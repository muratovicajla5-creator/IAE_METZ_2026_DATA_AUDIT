# %%
print("Analyse Bourse")
# Out:
# Analyse Bourse

# %% [markdown]
# # Let's go learning PYTHON !

# %%
# Ceci est un commentaire dans la cellule de code
# Python est de la programmation OBJET. On def des variables. 
name = "Ajla"

print(name)
# Out:
# Ajla

# %%
name
# si on appelle la variable alors on voit son type.
# Out:
# 'Ajla'

# %%
name = "Thomas"
name 
#la derniere def de variable l'emporte
# Out:
# 'Thomas'

# %%
# Pour les chiffres on a 
# LES ENTIERS NATURELS INTEGER
age = 26
print(age)
# Out:
# 26

# %%
# Pour les chiffres à virgules on parle de FLOATS 
pi = 3.14159
print(pi)
# Out:
# 3.14159

# %%
#un dictionnaire c'est une CLE VALEUR 

prices = {
    "APPL":248.04,
    "GOOGLE":328.33,
    "TSLA":437.43
}

# %%
prices
# Out:
# {'APPL': 248.04, 'GOOGLE': 328.33, 'TSLA': 437.43}

# %%
#commment avoir les données boursières ? 
#en effet on ne va pas recopier à la main des dictionnaires

# %%
#donc on utilise les PACKAGES 
! pip install yfinance
#YAHOO FINANCE
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 65.1 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 78.9 MB/s  0:00:006m0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 72.0 MB/s  0:00:00
# ...
#   Created wheel for multitasking: filename=multitasking-0.0.12-py3-none-any.whl size=15637 sha256=20342a0f1e7d8a742137236ea4f632f5287926cc2d5bf7fa5e426cc06c7c8599
#   Stored in directory: /home/codespace/.cache/pip/wheels/cc/bd/6f/664d62c99327abeef7d86489e6631cbf45b56fbf7ef1d6ef00
# Successfully built multitasking
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10/10 [yfinance]/10 [curl_cffi]]
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
! pip install matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 57.6 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 49.7 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 55.8 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 74.9 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [matplotlib]7 [matplotlib]
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
import yfinance as yf 
import pandas as pd 
import numpy as np
import matplotlib as plt

# %%
#la structure d'un projet python : 
# une cellule où l'on importe TOUS LES PACKAGES 
# comme ca on a une overview des DEPENDANCES

# %%
ticker = "AAPL"

# %%
# pour prendre les données du package yfinance on utilise 
# une FONCTION qui est def dans ce package pour extraire la donnée 
data = yf.download(ticker, start="2020-01-01", progress=False)

# %%
data
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2020-01-02   72.468246   72.528566   71.223244   71.476585  135480400
# 2020-01-03   71.763741   72.523769   71.539352   71.696183  146322800
# 2020-01-06   72.335564   72.374169   70.634547   70.885479  118387200
# 2020-01-07   71.995354   72.600960   71.775789   72.345204  108872000
# 2020-01-08   73.153481   73.455080   71.698566   71.698566  132079200
# ...                ...         ...         ...         ...        ...
# 2026-01-26  255.410004  256.559998  249.800003  251.479996   55969200
# 2026-01-27  258.269989  261.950012  258.209991  259.170013   49648300
# 2026-01-28  256.440002  258.859985  254.509995  257.649994   41288000
# 2026-01-29  258.279999  259.649994  254.410004  258.000000   67253000
# 2026-01-30  259.480011  261.899994  252.179993  255.169998   92352600
#
# [1528 rows x 5 columns]

# %%
data.head() #fct pour voir les 5 premières lignes du dataset
data.tail() # les 5 dernières
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker            AAPL        AAPL        AAPL        AAPL      AAPL
# Date
# 2026-01-26  255.410004  256.559998  249.800003  251.479996  55969200
# 2026-01-27  258.269989  261.950012  258.209991  259.170013  49648300
# 2026-01-28  256.440002  258.859985  254.509995  257.649994  41288000
# 2026-01-29  258.279999  259.649994  254.410004  258.000000  67253000
# 2026-01-30  259.480011  261.899994  252.179993  255.169998  92352600

# %%
name = 'Titouan'
# Titouan c est du text == STRING

# %%
# Mais nous sommes humains, donc nous LISONS des PHRASES. 
# Dès lors, on utilise la fonction PRINT F, qui permet d'avoir un print plus proche de notre language 
# Les variables y sont en DYNAMIQUES 
print(f'Hello, les boloss dont {name}')
# Out:
# Hello, les boloss dont Titouan

# %%
is_cool = True 
is_cool
# Out:
# True

# %% [markdown]
# # Presentation des DATA STRUCTURES

# %%
# Les LISTES se nomment list en anglais 
stocks = ["AAPL","GOOGL","MSFT","TSLA"]

# %%
stocks
# Out:
# ['AAPL', 'GOOGL', 'MSFT', 'TSLA']

# %%
# On peut AJOUTER des inputs dans la liste via la fonction APPEND 
stocks.append("AMZN")
stocks
# Out:
# ['AAPL', 'GOOGL', 'MSFT', 'TSLA', 'AMZN']

# %%
# UN DICTIONNAIRE c'est mieux encore qu'une liste
# On parle de Clé-Valeur 
prices = {
    "APPL":248.04,
    "GOOGLE":328.33,
    "TSLA":437.43
}

# %%
prices
# Out:
# {'APPL': 248.04, 'GOOGLE': 328.33, 'TSLA': 437.43}

# %% [markdown]
# # La clé du succès

# %%
# C est le fait que PYTHON repose sur des PACKAGES 
# Donc on gagne un temps fou à ne pas ré inventer la ROUE à chaque fois 
# ! pip install yfinance

# %%
import yfinance as yf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 import yfinance as yf
#
# ModuleNotFoundError: No module named 'yfinance'
